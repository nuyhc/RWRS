# %%
from ExpModule import *
exp_results = []

# %% [markdown]
# # Exp.

# %% [markdown]
# ## 1. Sample 10

# %%
exp_results.append(Train(10))
# Out:
# 10 10 10 10 10
# 보정전: 0.8
# 보정전: 0.6999999999999996
# 보정전: 0.5799999999999997
# 보정전: 0.6999999999999996
# 보정전: 0.5699999999999997
# C=0.67

# %% [markdown]
# ## 2. Sample 20

# %%
exp_results.append(Train(20))

# %% [markdown]
# ## Sample 30

# %%
exp_results.append(Train(30))

# %% [markdown]
# ## 4. Sample 40

# %%
exp_results.append(Train(40))

# %% [markdown]
# ## 5. Sample 50

# %%
exp_results.append(Train(50))
