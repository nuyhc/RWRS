# %%
from ExpModule import *

# %% [markdown]
# # Train w 5 ftrs

# %% [markdown]
# ## 1. Sample 10

# %%
r_10 = train_n(10, 5)
plot_static(r_10, 10, 5)
plot_kmeans(r_10, 0.9)
# Out:
# 10

# %% [markdown]
# ## 2. Sample 20

# %%
r_20 = train_n(20, 5)
plot_static(r_20, 20, 5)
plot_kmeans(r_20)

# %% [markdown]
# ## Samepl 30

# %%
r_30 = train_n(30, 5)
plot_static(r_30, 30, 5)
plot_kmeans(r_30)

# %%
r_100 = train_n(100, 5)
plot_static(r_100, 20, 5)
plot_kmeans(r_100)
# Out:
# 100 100 100 100 100
# 0.9 0.9 0.9 0.9 0.9

# %%
r_20 = train_n(20, 5)
plot_static(r_20, 20, 5)
plot_kmeans(r_20)
