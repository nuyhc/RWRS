# %%
from ExpModule import *
exp_result = []

# %%
train.shape, valid.shape
# Out:
# ((4674, 55), (1169, 55))

# %%
for sn in range(10, 4610, 10): # 350 ~
    exp_result.append(train_once(sn))

# %%
temp = (valid[target] - pred_k["Pred_Y"])/valid[target]

# %%
pd.concat(exp_result, axis=0)
# Out:
#    Sample#            LR        DT        RF    Kmeans  adj_Kmeans  adj_corr
# 0       10  1.803786e+00  1.229764  1.600216  4.410448    0.712996      0.10
# 0       20  1.900707e+00  0.895955  0.652288  2.390073    0.730611      0.17
# 0       30  1.657144e+00  0.561640  0.609891  2.500376    0.770943      0.15
# 0       40  1.149429e+00  0.529462  0.491052  2.308595    0.797051      0.14
# 0       50  1.308861e+00  0.537650  0.492173  2.150249    0.813223      0.15
# 0       60  6.536684e+05  0.555351  0.503852  2.042998    0.796388      0.16
# 0       70  4.339347e+06  0.562315  0.508139  2.211804    0.789082      0.15
# 0       80  5.982632e+06  0.587413  0.502641  2.168787    0.770812      0.15
# 0       90  7.190969e+05  0.564867  0.470905  2.191531    0.778103      0.15
# 0      100  9.136788e-01  0.562966  0.484075  2.078502    0.770405      0.16
# 0      110  8.772931e-01  0.564018  0.484037  1.918031    0.762853      0.20
# ...
